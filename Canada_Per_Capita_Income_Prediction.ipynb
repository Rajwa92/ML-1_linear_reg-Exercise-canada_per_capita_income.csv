# %% [markdown]
# <a href="https://colab.research.google.com/github/rajwa-salem/ML-1_linear_reg-Exercise-canada_per_capita_income.csv/blob/main/Canada_Per_Capita_Income_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Exercise**
# > Predict canada's per capita income in year 2020. There is an exercise folder here on github at same level as this notebook, download that and you will find canada_per_capita_income.csv file. Using this build a regression model and predict the per capita income fo canadian citizens in year 2020
#
# **Answer**
# > 41288.69409442

# %%
# import the required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import linear_model
# %matplotlib inline

# %%
df = pd.read_csv('/content/canada_per_capita_income.csv')
df
# Out:
#     year  per capita income (US$)
# 0   1970              3399.299037
# 1   1971              3768.297935
# 2   1972              4251.175484
# 3   1973              4804.463248
# 4   1974              5576.514583
# 5   1975              5998.144346
# 6   1976              7062.131392
# 7   1977              7100.126170
# 8   1978              7247.967035
# 9   1979              7602.912681
# 10  1980              8355.968120
# 11  1981              9434.390652
# 12  1982              9619.438377
# 13  1983             10416.536590
# 14  1984             10790.328720
# 15  1985             11018.955850
# 16  1986             11482.891530
# 17  1987             12974.806620
# 18  1988             15080.283450
# 19  1989             16426.725480
# 20  1990             16838.673200
# 21  1991             17266.097690
# 22  1992             16412.083090
# 23  1993             15875.586730
# 24  1994             15755.820270
# 25  1995             16369.317250
# ...

# %%
df.head()
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583

# %%
plt.title('PER CAPITA IN USD')
plt.plot(df.year, df["per capita income (US$)"], label = "Per capita curve")
plt.xlabel("year")
plt.ylabel("per capita income (US$)")
plt.grid()
plt.legend()

# %%
# initialize the linear regression model
reg=linear_model.LinearRegression()
reg
# Out:
# LinearRegression()

# %%
# Lets fit the model
reg.fit(df[['year']].values,df[['per capita income (US$)']].values)
# Out:
# LinearRegression()

# %%
# lets predict
reg.predict([[2020]])
# Out:
# array([[41288.69409442]])

# %% [markdown]
# **The above prediction says that, in the year 2020 the Canada per capita income will be 41288.69409442(US $)**
#
#  Verfication of the Linear Regression machine learning algorithm with the help of y = m * x + b
#
#
# > y = m * x + b
#
# > where
# * y=dependent variable
# * m=coefficient
# * independant variable
# * b=intercept

# %%
# coefficient
reg.coef_
# Out:
# array([[828.46507522]])

# %%
# intercept
reg.intercept_
# Out:
# array([-1632210.75785546])

# %%
# y=mx+b
828.46507522*2020+(-1632210.75785546)
# Out:
# 41288.69408894004

# %% [markdown]
# **Verified, hence we can say that the output of the machine learning algorithm is true.**
